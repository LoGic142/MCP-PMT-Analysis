# %%
import pandas as pd

# %%
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv("PMT EVENING.csv")

# %%
df.head()
# Out:
#    S.No.    Entry No.           Student Name  G  SG Q1(30)  LAB(25)  PMT(55)  \
# 0    1.0  2020CE10210         ABHISHEK JATAV  1  1J      1    19.75    20.75
# 1    2.0  2020CE10211         ABHISHEK KUMAR  1  1J   5.25    21.50    26.75
# 2    3.0  2020CE10216                  ADITI  1  1J      0    22.00    22.00
# 3    4.0  2020CE10218  ADITYA SINGH NIRANJAN  1  1J      4    21.25    25.25
# 4    5.0  2020CE10221          AKSHAT SHUKLA  1  1J   1.25    20.25    21.50
#
#    Unnamed: 8
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df2=df[df['Q1(30)']!='AB']

# %%
df2['Q1(30)']=df2['Q1(30)'].astype('float')

# %%
df2[df2['Q1(30)']>=10].sort_values('Q1(30)',ascending=False)
# Out:
#      S.No.    Entry No.            Student Name  G  SG  Q1(30)  LAB(25)  \
# 186  187.0  2020ME21003              ARUN VERMA  2  2L   15.50    22.25
# 40    41.0  2020EE10473            ANUJ PRADHAN  1  1K   15.25    23.00
# 46    47.0  2020EE10501            JIVESH KESAR  1  1K   14.75    21.25
# 485  483.0  2020MT60618         PRIYANSHU YADAV  5  5L   14.00    22.50
# 321  322.0  2020TT11111        GARIMA CHOUDHARY  3  3N   13.75    20.25
# 74    75.0  2020ME10909            AMIT AGRAWAL  1  1L   13.25    22.00
# 322  323.0  2020TT11115             GUNJAN MODI  3  3N   12.75    22.25
# 205  206.0  2020ME21066             TARUN VERMA  2  2M   12.25    22.25
# 435  433.0  2020MT10128            SHIVAM MADAN  5  5J   12.25    22.25
# 356  354.0  2020BB10034           NISCHAL GUPTA  4  4J   12.25    22.25
# 39    40.0  2020EE10469            ANIRUDH GARG  1  1K   12.00    20.25
# 47    48.0  2020EE10505        KARTIKEY AGARWAL  1  1K   11.50    20.75
# ...

# %%
df2.describe()

# %%
df.sort_values('Q1(30)')

# %%
df.nlargest(10,'PMT(55)',keep='all')
# Out:
#      S.No.    Entry No.     Student Name  G  SG Q1(30)  LAB(25)  PMT(55)  \
# 40    41.0  2020EE10473     ANUJ PRADHAN  1  1K  15.25    23.00    38.25
# 186  187.0  2020ME21003       ARUN VERMA  2  2L   15.5    22.25    37.75
# 485  483.0  2020MT60618  PRIYANSHU YADAV  5  5L     14    22.50    36.50
# 46    47.0  2020EE10501     JIVESH KESAR  1  1K  14.75    21.25    36.00
# 74    75.0  2020ME10909     AMIT AGRAWAL  1  1L  13.25    22.00    35.25
# 322  323.0  2020TT11115      GUNJAN MODI  3  3N  12.75    22.25    35.00
# 372  370.0  2020BB10066         YASHDEEP  4  4K   10.5    24.25    34.75
# 447  445.0  2020MT10797      DAYAL KUMAR  5  5J   11.5    23.25    34.75
# 205  206.0  2020ME21066      TARUN VERMA  2  2M  12.25    22.25    34.50
# 356  354.0  2020BB10034    NISCHAL GUPTA  4  4J  12.25    22.25    34.50
# 435  433.0  2020MT10128     SHIVAM MADAN  5  5J  12.25    22.25    34.50
# 438  436.0  2020MT10777    AADYA AGRAWAL  5  5J  11.25    23.25    34.50
#
#      Unnamed: 8
# ...

# %%
df['rank']=df['PMT(55)'].rank(method='min',ascending=False).astype(int)

# %%
df.sort_values('rank').head(15)
# Out:
#      S.No.    Entry No.      Student Name  G  SG Q1(30)  LAB(25)  PMT(55)  \
# 40    41.0  2020EE10473      ANUJ PRADHAN  1  1K  15.25    23.00    38.25
# 186  187.0  2020ME21003        ARUN VERMA  2  2L   15.5    22.25    37.75
# 485  483.0  2020MT60618   PRIYANSHU YADAV  5  5L     14    22.50    36.50
# 46    47.0  2020EE10501      JIVESH KESAR  1  1K  14.75    21.25    36.00
# 74    75.0  2020ME10909      AMIT AGRAWAL  1  1L  13.25    22.00    35.25
# 322  323.0  2020TT11115       GUNJAN MODI  3  3N  12.75    22.25    35.00
# 447  445.0  2020MT10797       DAYAL KUMAR  5  5J   11.5    23.25    34.75
# 372  370.0  2020BB10066          YASHDEEP  4  4K   10.5    24.25    34.75
# 435  433.0  2020MT10128      SHIVAM MADAN  5  5J  12.25    22.25    34.50
# 205  206.0  2020ME21066       TARUN VERMA  2  2M  12.25    22.25    34.50
# 356  354.0  2020BB10034     NISCHAL GUPTA  4  4J  12.25    22.25    34.50
# 438  436.0  2020MT10777     AADYA AGRAWAL  5  5J  11.25    23.25    34.50
# ...

# %%
df.nlargest(10,'PMT(55)').shape
# Out:
# (10, 9)

# %%
df.nlargest(10,'PMT(55)',keep='all').shape
# Out:
# (12, 9)

# %%
df.sort_values(['PMT(55)','LAB(25)'],ascending=[False,False]).head(10)
# Out:
#      S.No.    Entry No.     Student Name  G  SG Q1(30)  LAB(25)  PMT(55)  \
# 40    41.0  2020EE10473     ANUJ PRADHAN  1  1K  15.25    23.00    38.25
# 186  187.0  2020ME21003       ARUN VERMA  2  2L   15.5    22.25    37.75
# 485  483.0  2020MT60618  PRIYANSHU YADAV  5  5L     14    22.50    36.50
# 46    47.0  2020EE10501     JIVESH KESAR  1  1K  14.75    21.25    36.00
# 74    75.0  2020ME10909     AMIT AGRAWAL  1  1L  13.25    22.00    35.25
# 322  323.0  2020TT11115      GUNJAN MODI  3  3N  12.75    22.25    35.00
# 372  370.0  2020BB10066         YASHDEEP  4  4K   10.5    24.25    34.75
# 447  445.0  2020MT10797      DAYAL KUMAR  5  5J   11.5    23.25    34.75
# 438  436.0  2020MT10777    AADYA AGRAWAL  5  5J  11.25    23.25    34.50
# 205  206.0  2020ME21066      TARUN VERMA  2  2M  12.25    22.25    34.50
#
#      Unnamed: 8  rank
# 40          NaN     1
# 186         NaN     2
# 485         NaN     3
# 46          NaN     4
# 74          NaN     5
# 322         NaN     6
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Out:
# <AxesSubplot:>

# %%
df2.describe()
# Out:
#             S.No.           G      Q1(30)     LAB(25)     PMT(55)  Unnamed: 8
# count  514.000000  516.000000  516.000000  516.000000  516.000000         0.0
# mean   261.861868    2.846899    5.366182   20.957849   26.324031         NaN
# std    152.131568    1.417577    3.034818    1.996305    3.898360         NaN
# min      1.000000    1.000000    0.000000    4.000000    4.500000         NaN
# 25%    130.250000    2.000000    3.250000   20.500000   24.000000         NaN
# 50%    261.500000    3.000000    5.250000   21.250000   26.250000         NaN
# 75%    392.750000    4.000000    7.500000   22.000000   29.000000         NaN
# max    527.000000    5.000000   15.500000   24.250000   38.250000         NaN

# %%
df2.groupby('SG')['PMT(55)'].max().reset_index()
# Out:
#     SG  PMT(55)
# 0   1J    30.75
# 1   1K    38.25
# 2   1L    35.25
# 3   1M    31.25
# 4   1N    30.75
# 5   2J    30.50
# 6   2K    31.25
# 7   2L    37.75
# 8   2M    34.50
# 9   2N    32.25
# 10  3J    30.25
# 11  3K    32.25
# 12  3L    31.50
# 13  3M    33.25
# 14  3N    35.00
# 15   4    22.50
# 16  4J    34.50
# 17  4K    34.75
# 18  4L    30.50
# 19  4M    32.50
# 20  4N    30.75
# 21  5B    12.25
# 22  5J    34.75
# 23  5K    33.25
# 24  5L    36.50
# 25  5M    30.00
# 26  5N    32.25

# %%
type(df2.groupby('SG')['PMT(55)'].max().reset_index())
# Out:
# pandas.core.frame.DataFrame

# %%
type(df2.groupby('SG')['PMT(55)'].max())
# Out:
# pandas.core.series.Series

# %%
df2.query('SG=="5B"')
# Out:
#      S.No.    Entry No.      Student Name  G  SG  Q1(30)  LAB(25)  PMT(55)  \
# 530    NaN  2020AM10662  Preeti Choudhary  5  5B     0.0    12.25    12.25
#
#      Unnamed: 8
# 530         NaN

# %%
s='Aditya Raj'

# %%
df[df['Student Name']==('JAIVARDHAN SINGH SHEKHA').upper()]
# Out:
#      S.No.    Entry No.             Student Name  G  SG Q1(30)  LAB(25)  \
# 323  324.0  2020TT11119  JAIVARDHAN SINGH SHEKHA  3  3N   3.25    21.25
#
#      PMT(55)  Unnamed: 8  rank
# 323     24.5         NaN   353

# %%
df.query('rank==353').sort_values('Q1(30)')
# Out:
#      S.No.    Entry No.             Student Name  G  SG Q1(30)  LAB(25)  \
# 390  388.0  2020EE10476              ARYAN SINHA  4  4L   1.25    23.25
# 233  234.0  2020CE10213          ABHISHEK PANDEY  3  3J   2.75    21.75
# 365  363.0  2020BB10052          SHANTANU KARTHA  4  4K   2.75    21.75
# 323  324.0  2020TT11119  JAIVARDHAN SINGH SHEKHA  3  3N   3.25    21.25
# 489  487.0  2020MT60871              ARYAN KUMAR  5  5L   3.25    21.25
# 192  193.0  2020ME21027      KHER ABHIMAN ANUPAM  2  2M    3.5    21.00
# 288  289.0  2020ME10956            RADHIKA AGWAN  3  3L    3.5    21.00
# 244  245.0  2020CE10268              PALAK GOYAL  3  3J   3.75    20.75
# 209  210.0  2020TT11080           ADITYA NAGDEVE  2  2M   4.25    20.25
# 419  417.0  2020TT11108           DEVJAYA BISWAS  4  4N   4.25    20.25
# 62    63.0  2020EE10557               SRIKANTH R  1  1L   4.75    19.75
#
#      PMT(55)  Unnamed: 8  rank
# 390     24.5         NaN   353
# 233     24.5         NaN   353
# ...

# %%
len(df.query('rank==353').sort_values('Q1(30)'))
# Out:
# 11

# %%
df.query('rank==301')
# Out:
#      S.No.    Entry No.             Student Name  G  SG Q1(30)  LAB(25)  \
# 53    54.0  2020EE10521  PERUGU KRISHNA CHAITANY  1  1L   4.75    20.75
# 67    68.0  2020EE10583             ANURAG GUPTA  1  1L      4    21.50
# 72    73.0  2020ME10900                 ACHINTYA  1  1L   8.25    17.25
# 116  117.0  2020TT11157               ROHIT SHAW  1  1N   4.75    20.75
# 145  146.0  2020CE10279    RANDEEP SINGH SANGWAN  2  2K      4    21.50
# 170  171.0  2020EE30606       NEERAJ KUMAR MEENA  2  2L   5.25    20.25
# 214  215.0  2020TT11106        DEEP RATAN GAUTAM  2  2N   3.75    21.75
# 272  273.0  2020ME10902                   ADITYA  3  3K      5    20.50
# 297  298.0  2020ME10983            VIRAJ AGRAWAL  3  3L    4.5    21.00
# 302  303.0  2020PH10688          BHAKTI CHOUKSEY  3  3M    4.5    21.00
# 402  400.0  2020EE10532         PUSHPENDRA MEENA  4  4M   5.75    19.75
# 425  423.0  2020TT11144                  NIRUPAM  4  4N      6    19.50
# ...

# %%
len(df.query('rank==301'))
# Out:
# 13

# %%
df[df['Student Name']=='AD']
# Out:
#      S.No.    Entry No. Student Name  G  SG Q1(30)  LAB(25)  PMT(55)  \
# 425  423.0  2020TT11144      NIRUPAM  4  4N      6     19.5     25.5
#
#      Unnamed: 8  rank
# 425         NaN   301

# %%
df[df['Student Name']=='ADITYA RAJ']
# Out:
#      S.No.    Entry No. Student Name  G  SG Q1(30)  LAB(25)  PMT(55)  \
# 314  315.0  2020TT11081   ADITYA RAJ  3  3M     AB     21.5     21.5
#
#      Unnamed: 8  rank
# 314         NaN   465

# %%
df.query('SG=="3N"')
# Out:
#      S.No.    Entry No.             Student Name  G  SG Q1(30)  LAB(25)  \
# 319  320.0  2020TT11103        JASH PRAFULL BAUA  3  3N   8.75    20.50
# 320  321.0  2020TT11107               DEV PRATAP  3  3N   9.25    22.50
# 321  322.0  2020TT11111         GARIMA CHOUDHARY  3  3N  13.75    20.25
# 322  323.0  2020TT11115              GUNJAN MODI  3  3N  12.75    22.25
# 323  324.0  2020TT11119  JAIVARDHAN SINGH SHEKHA  3  3N   3.25    21.25
# 324  325.0  2020TT11123                   KARTIK  3  3N      6    15.50
# 325  326.0  2020TT11127            KULVEER SINGH  3  3N     10    21.50
# 326  327.0  2020TT11131            MANAN AGARWAL  3  3N     AB    22.00
# 327  328.0  2020TT11135          MOHAMMED ROSHAN  3  3N      5    19.75
# 328  329.0  2020TT11139             NIDHI SINGHI  3  3N    9.5    21.50
# 329  330.0  2020TT11143           NIRANJAN KUMAR  3  3N     10    16.00
# 330  331.0  2020TT11147    PRAGYANSH PRIYADARSHI  3  3N    8.5    21.25
# ...

# %%
plt.figure(figsize=(16,9),dpi=200)

sns.scatterplot(x='LAB(25)',y='Q1(30)',data=df2)
plt.axvline(x=df2['LAB(25)'].mean(),c='red')
plt.axhline(y=df2['Q1(30)'].mean(),c='black')

# %%
df2[(df2['LAB(25)']<=19) & (df2['Q1(30)'] >=df2['Q1(30)'].mean())]
# Out:
#      S.No.    Entry No.               Student Name  G  SG  Q1(30)  LAB(25)  \
# 50    51.0  2020ME10960                  RAJ KUMAR  1  1K    7.00    18.75
# 59    60.0  2020EE10545             SAMIKSHA SAGAR  1  1L    6.75    16.50
# 72    73.0  2020ME10900                   ACHINTYA  1  1L    8.25    17.25
# 75    76.0  2020ME10912                ANKIT MEENA  1  1M    7.50    17.75
# 139  140.0  2020CE10259             MANIKYA MAYANK  2  2J    7.75     9.25
# 180  181.0  2020EE30634                VIVEK KUMAR  2  2L    6.00    17.00
# 191  192.0  2020ME21024            IKJOT SINGH DUA  2  2M    7.00    18.25
# 202  203.0  2020ME21057                SHUCHI JAIN  2  2M   11.50    17.00
# 203  204.0  2020ME21060               STUTI LOHANI  2  2M   10.25    17.50
# 206  207.0  2020ME21069                VARUN PATEL  2  2M   10.00    14.25
# 218  219.0  2020TT11122                 JAYA YADAV  2  2N    6.75    17.25
# ...

# %%
df2['dept']=df2['Entry No.'].str[4:6]

# %%
df3=df2.query('dept=="EE"')

# %%
# Out:
#      S.No.    Entry No.           Student Name  G  SG  Q1(30)  LAB(25)  \
# 0      1.0  2020CE10210         ABHISHEK JATAV  1  1J    1.00    19.75
# 1      2.0  2020CE10211         ABHISHEK KUMAR  1  1J    5.25    21.50
# 2      3.0  2020CE10216                  ADITI  1  1J    0.00    22.00
# 3      4.0  2020CE10218  ADITYA SINGH NIRANJAN  1  1J    4.00    21.25
# 4      5.0  2020CE10221          AKSHAT SHUKLA  1  1J    1.25    20.25
# ..     ...          ...                    ... ..  ..     ...      ...
# 526  524.0  2020PH10725           SAMYAK GOTHI  5  5N    9.00    21.00
# 527  525.0  2020PH10729            SARA ROSHEN  5  5N    4.00    22.00
# 528  526.0  2020PH10733           TUSHAR KUMAR  5  5N    2.75    19.00
# 529  527.0  2020PH11194        DIVYE CHOUDHARY  5  5N    4.50    19.00
# 530    NaN  2020AM10662       Preeti Choudhary  5  5B    0.00    12.25
#
#      PMT(55)  Unnamed: 8 dept
# 0      20.75         NaN   CE
# 1      26.75         NaN   CE
# ...

# %%
plt.figure(figsize=(16,9),dpi=200)


sns.scatterplot(x='LAB(25)',y='Q1(30)',data=df2,hue='dept')
plt.axvline(x=df2['LAB(25)'].mean(),c='red')
plt.axhline(y=df2['Q1(30)'].mean(),c='black')

# %%
plt.figure(figsize=(16,9),dpi=200)


sns.scatterplot(x='LAB(25)',y='Q1(30)',data=df2,hue='dept',size='PMT(55)')
plt.axvline(x=df2['LAB(25)'].mean(),c='red')
plt.axhline(y=df2['Q1(30)'].mean(),c='black')

# %%
df2.groupby('dept').agg({'Q1(30)':'mean','LAB(25)':'mean'}).sort_values(['LAB(25)'],ascending=False)
# Out:
#         Q1(30)    LAB(25)
# dept
# MT    5.616667  21.946667
# CH    6.215625  21.593750
# BB    6.201613  21.338710
# EE    5.205556  21.058333
# PH    5.116071  21.044643
# ME    6.436747  20.831325
# CE    3.896465  20.739899
# TT    5.637097  20.239247
# AM    0.000000  12.250000

# %%
df3[(df3['LAB(25)']<=19) & (df2['Q1(30)'] >=df2['Q1(30)'].mean())]

# %%
plt.figure(figsize=(16,9),dpi=200)


sns.scatterplot(x='LAB(25)',y='Q1(30)',data=df3)
plt.axvline(x=df2['LAB(25)'].mean(),c='red')
plt.axhline(y=df2['Q1(30)'].mean(),c='black')

# %%
df2.corr()
# Out:
#                S.No.         G    Q1(30)   LAB(25)   PMT(55)  Unnamed: 8
# S.No.       1.000000  0.978300  0.080394  0.142993  0.136046         NaN
# G           0.978300  1.000000  0.052550  0.160161  0.122926         NaN
# Q1(30)      0.080394  0.052550  1.000000  0.165212  0.863089         NaN
# LAB(25)     0.142993  0.160161  0.165212  1.000000  0.640704         NaN
# PMT(55)     0.136046  0.122926  0.863089  0.640704  1.000000         NaN
# Unnamed: 8       NaN       NaN       NaN       NaN       NaN         NaN

# %%
df2.sample(5)
# Out:
#      S.No.    Entry No.     Student Name  G  SG  Q1(30)  LAB(25)  PMT(55)  \
# 70    71.0  2020EE10603  KUSHAGRA MITTAL  1  1L    2.50    21.50    24.00
# 426  424.0  2020TT11148    PRASHANT GILL  4  4N    0.00    20.50    20.50
# 178  179.0  2020EE30630    VARNIKA BHATT  2  2L    3.75    20.50    24.25
# 318  319.0  2020TT11099     ASMITA MEHTA  3  3M    5.50    22.25    27.75
# 416  414.0  2020TT11092    ANKUSH RATHEE  4  4M    3.75    22.00    25.75
#
#      Unnamed: 8
# 70          NaN
# 426         NaN
# 178         NaN
# 318         NaN
# 416         NaN

# %%
Jaivardhan Singh Shekhawat

# %%
A
